# %%
from skimage import data
from skimage.filters import gaussian
import numpy as np
from scipy.stats import moment
from skimage import feature
import matplotlib.pyplot as plt

# %%
image = data.coins()
plt.imshow(image, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 383.5, 302.5, -0.5)

# %%
m_int = np.mean(image)
m_std = np.std(image)
min_int = np.min(image)
max_int = np.max(image)
m_2 = moment(image, moment=2, axis=None)
m_3 = moment(image, moment=3, axis=None)
m_4 = moment(image, moment=4, axis=None)

# %%
m_2 = moment(image, moment=1, axis=None)

# %%
np.mean(np.array([1, 2, 3, 4, 5]))
# Out:
# 3.0

# %%
edges = feature.canny(gaussian(image, sigma=1))
plt.imshow(edges, cmap='gray')

# %%
np.mean(edges)
# Out:
# 0.08170035753575358
